# %% [markdown]
# # Explorando Fractais com Python: O Floco de neve Koch

# %% [markdown]
# - PET - Física
# - Petiana: Cecília Nunes de Carvalho
# - Data: 12 de maio de 2026

# %% [markdown]
# Este ```Notebook``` está organizado da seguinte forma:
# 1. _Introdução ao mundo dos fractais_;
# 2. _O floco de neve_;
# 3. _Desenhando_;
# 4. _Área vs Perímetro_;
# 5. _Conclusão_;

# %% [markdown]
# ## Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
from turtle import *

# %% [markdown]
# ## Informações sobre as bibliotecas

# %%
# %load_ext version_information
# %version_information Matplotlib, Numpy
# Out:
# Software versions
# Python 3.11.7 64bit [MSC v.1916 64 bit (AMD64)]
# IPython 8.20.0
# OS Windows 10 10.0.26200 SP0
# Matplotlib 3.8.0
# Numpy 1.26.4
# Fri May 15 01:15:14 2026 Hora oficial do Brasil

# %% [markdown]
# ## 1. Introdução ao mundo dos fractais

# %% [markdown]
# $\quad$ O que é um fractal, afinal? É provável que você já tenha visto alguma das seguintes imagens pela internet, em contextos relacionados à matemática ou à física. Mas muitos não sabem o que estas imagens representam, tampouco conhecem as curiosidades matemáticas por trás delas.

# %% [markdown]
# ![mandelbrot](https://upload.wikimedia.org/wikipedia/commons/2/21/Mandel_zoom_00_mandelbrot_set.jpg)

# %% [markdown]
# $\quad$ Em sua definição geral, um fractal é uma forma geométrica que contém estruturas detalhadas a escalas arbitrariamente pequenas, geralmente com uma _dimensão fractal_ excedente à sua _dimensão topológica_ (não se preocupe, detalharei o que estes termos significam em breve). Muitos fractais apresentam semelhanças em diversas escalas, como ilustrado em ampliações sucessivas do conjunto de Mandelbrot, representado pela figura acima. Essa exibição de padrões semelhantes em escalas cada vez menores é chamada de autossimilaridade, também conhecida como simetria expansiva ou simetria de desdobramento.

# %% [markdown]
# $\quad$ Uma das maneiras pelas quais os fractais diferem de outras figuras geométricas é a forma como escalam. Dobrar o comprimento das arestas de um polígono preenchido multiplica sua área por quatro, que é dois (a razão entre o novo e o antigo comprimento da aresta) elevado à potência de dois (a dimensão convencional do polígono preenchido). Da mesma forma, se o raio de uma esfera preenchida for dobrado, seu volume aumenta por oito, que é dois (a razão entre o novo e o antigo raio) elevado à potência de três (a dimensão convencional da esfera preenchida). No entanto, se os comprimentos unidimensionais de um fractal forem todos dobrados, o conteúdo espacial do fractal escala por uma potência que não é necessariamente um número inteiro e, em geral, é maior que sua dimensão convencional. Essa potência é chamada de _dimensão fractal_ do objeto geométrico, para distingui-la da dimensão convencional, que é formalmente chamada de _dimensão topológica_.

# %% [markdown]
# $\quad$ O nome "fractal" foi escolhido pelo matemático Benoit Mandelbrot em 1975, que se baseou no latim _frāctus_, significando fratura, algo quebrado. Ele usou este termo principalmente para relacionar suas ideias teóricas sobre dimensões fractais com padrões geométricos encontrados na natureza. Estes fractais aproximados presentes no meio ambiente exibem autossimilaridade em escalas extensas, porém finitas. Alguns fenômenos naturais em que podemos encontrar características fractais são, por exemplo, vasos sanguíneos, flocos de neve, árvores, neurônios, os anéis de saturno, entre outros. Abaixo, você pode observar exemplos destes padrões na forma de cristais de gelo e "cicatrizes" causadas por raios (também chamadas de figuras de Lichtenberg).

# %% [markdown]
# ![frost crystals](https://upload.wikimedia.org/wikipedia/commons/thumb/0/0a/Frost_patterns_2.jpg/960px-Frost_patterns_2.jpg)
#
# **Figura 2:** Padrão formado por descarga elétrica de alta voltagem em um bloco de acrílico de 100mm.

# %% [markdown]
# ![lichtenberg](https://upload.wikimedia.org/wikipedia/commons/thumb/5/55/Lichtenberg_figure_in_block_of_Plexiglas.jpg/500px-Lichtenberg_figure_in_block_of_Plexiglas.jpg)
#
# **Figura 3:** Cristais de gelo que ocorrem naturalmente em vidro frio, formando padrões fractais.

# %% [markdown]
# ## 2. O floco de neve

# %% [markdown]
# $\quad$ Neste ```Notebook```, iremos focar em um padrão fractal específico, conhecido como o floco de neve de Koch. Este fractal é baseado na curva de Koch, descrita pela primeira vez em 1904 pelo matemático sueco Niels Fabian Helge van Koch, em seu trabalho "Sur une courbe continue sans tangente, obtenue par une construction géométrique élémentaire" (Em uma curva contínua sem tangentes, construtível a partir da geometria elementar).

# %% [markdown]
# $\quad$ Uma curva de Koch é construída da seguinte maneira: primeiro, separamos um segmento de reta qualquer.
#
# ![Captura de tela 2026-05-13 144301.png](attachment:e8a43fb2-a6c6-4320-acae-34719196be77.png)
#
# Em seguida, dividimos a reta em 3 partes de mesmo comprimento.
#
# ![Captura de tela 2026-05-13 144453.png](attachment:44269fda-8dc3-4fa3-9dd7-44d0584fcb8f.png)
#
# Agora, removemos a seção central e a substituímos por dois lados de um triângulo equilátero (cujos lados têm o mesmo comprimento que o segmento removido).
#
# ![Captura de tela 2026-05-13 144716.png](attachment:55d3dd53-55c8-44f8-80f5-7a8f9690d56d.png)
#
# Agora temos uma forma composta por quatro segmentos de igual comprimento! Esta seria a primeira iteração da nossa curva de Koch. Podemos obter a segunda iteração repetindo o mesmo processo em cada um desses 4 segmentos:
#
# ![Captura de tela 2026-05-13 144937.png](attachment:dd1d06a6-fe73-4071-8617-7ddb6df2eb44.png)
#
# Aplicando os mesmos princípios na segunda iteração, obtemos a terceira iteração.
#
# ![Captura de tela 2026-05-13 145206.png](attachment:0c3750d7-c9ba-432d-b9e3-f77f5fe05b54.png)
#
# Se continuarmos este processo infinitamente, obteremos curvas cada vez intrincadas. A curva torna-se cada vez mais longa e tortuosa, embora a distância geométrica entre os pontos finais permaneça a mesma; a linha simplesmente "se dobra" sobre si mesma.
#
# ![Captura de tela 2026-05-13 145528.png](attachment:9c9c8703-d8df-408f-aef6-05efcf8c75b2.png)

# %% [markdown]
# Mas como transformamos isto em um floco de neve? Tudo que precisamos fazer é usar um triângulo equilátero na nossa primeira iteração:
#
# ![hahahakoch](https://upload.wikimedia.org/wikipedia/commons/thumb/d/d9/KochFlake.svg/960px-KochFlake.svg.png)

# %% [markdown]
# $\quad$ Uma curiosidade sobre o floco de neve Koch é que, se dermos zoom em um vértice da figura, fica fácil visualizar a autossimilaridade deste fractal. Ele sempre parece o mesmo, não importa de quão longe ou de quão perto você o observe.
#
# ![Kochsim.gif](attachment:d0bf79dd-9aed-4acb-9922-7522620aafcc.gif)
#
# **Figura 3:** animação dando zoom em um dos vértices do floco de neve Koch.

# %% [markdown]
# $\quad$ No entanto, se dermos zoom em um ponto que não é vértice, a figura parece girar!
#
# ![Zooming_in_a_point_of_Koch_curve_that_is_not_a_vertex.gif](attachment:1dc8bc10-8ba9-46cd-aa33-058e7b653ec1.gif)
#
# **Figura 4:** animação dando zoom em um ponto que não é vértice faz com que a curva gire.

# %% [markdown]
# $\quad$ O nosso floco de neve possui uma dimensão topológica de 1, mas não é de forma alguma retificável: o comprimento da curva entre quaisquer dois pontos no floco de neve de Koch é infinito. Nenhum pequeno pedaço dele é linear, mas sim composto por um número infinito de segmentos unidos em ângulos diferentes. A dimensão fractal de uma curva pode ser explicada intuitivamente pensando em uma linha fractal como um objeto detalhado demais para ser unidimensional, mas simples demais para ser bidimensional. Portanto, sua dimensão pode ser melhor descrita não por sua dimensão topológica usual de 1, mas por sua dimensão fractal, que geralmente é um número entre um e dois; no caso do floco de neve de Koch, é aproximadamente 1,2619.
# Podemos calcular isso utilizando o fator de escala ($S = 3$) e o número de objetos auto-semelhantes ($N = 4$) para calcular a dimensão, $D$, após a primeira iteração, sendo
# $$D = \frac{\ln N}{\ln S} = \frac{\ln 4}{\ln 3} \approx 1,2619.$$

# %% [markdown]
# ## 3. Desenhando

# %% [markdown]
# $\quad$ Agora que entendemos como é formado um Floco de neve Koch, podemos desenhá-lo com ajuda do ```python```. Para isso, vamos usar uma biblioteca chamada ```turtle```, em que podemos controlar uma "tartaruguinha" que anda pela tela e desenha de acordo com o algoritmo que inserirmos no código. Somos capazes de fazer isso com o Floco de neve pois ele pertence a um grupo específico de fractais chamados _iterated function system fractals_ (fractais de sistema de função iterada), ou fractais IFS. Os principais conceitos por trás da geração desses fractais IFS são a recursão e o sistema Lindenmayer.

# %% [markdown]
# $\quad$ Se você já é familiarizada(o) com programação, deve saber que uma função recursiva é uma função que chama a si mesma durante sua execução, como a função ```koch_flake``` exemplificada abaixo. No corpo da função, utilizamos o sistema Lindenmayer (ou _L-system_), que representa um fractal como uma série de regras a ser seguidas; é um sistema de reescrita paralela e um tipo de gramática formal. Um _L-system_ consiste em um alfabeto de símbolos que podem ser usados ​​para formar cadeias de caracteres, um conjunto de regras de produção que expandem cada símbolo em uma cadeia maior de símbolos, uma cadeia inicial ("axioma") a partir da qual se inicia a construção e um mecanismo para traduzir as cadeias geradas em estruturas geométricas. Vamos observar como escreveríamos um floco de neve Koch em Lindenmayer:
#
# - axioma = “F--F--F”;
#
# - regras = {“F”:”F+F--FF+F”;”}
#
# - iterações = 4;
#
# - ângulo = 60°.

# %% [markdown]
# $\quad$ Mas o que significa cada uma dessas coisas? Primeiramente, um axioma é a figura geométrica inicial. As regras são as direções em que a figura inicial deve ser alterada para se obter o fractal desejado, e o ângulo é o ângulo de rotação da nossa tartaruga. As iterações são o número de vezes que o código deve ser executado para se obter o fractal final. Já o ```F```, ```+``` e ```-``` são variáveis: ```F``` significa dar um passo à frente, ```+``` é virar à direita, e ```-``` é virar à esquerda (de acordo com o ângulo de rotação).

# %%
def koch_flake(length, order): #aqui, temos uma função que recebe variáveis para tamanho e ordem do floco de neve.
    if(order == 0): #a ordem será a quantidade de vezes que teremos feito o processo de divisão de cada um dos lados do triângulo.
        forward(length)
        return
    koch_flake(length/3,order-1) #aqui, utilizamos uma função recursiva que chama a si mesma de acordo com a lógica do L-system.
    left(60)
    koch_flake(length/3, order - 1)
    right(120)
    koch_flake(length/3, order - 1)
    left(60)
    koch_flake(length/3,order-1)

# %%
def draw_flake(): #agora, definiremos nossa função que de fato desenha nosso fractal!
    speed(0)
    up()
    backward(200 / 2.0)
    down()
    color('black')
    fillcolor('white')
    begin_fill()
    for i in range(3):
        koch_flake(300.0, 4) #chamamos a função recursiva de tamanho 300 e ordem 4
        left(-120)
    end_fill()
    mainloop()
    
draw_flake() #rodando a função

# %% [markdown]
# ![Captura de tela 2026-05-13 134650.png](attachment:9f9ed797-6a76-4b40-b58e-949074233a37.png)

# %% [markdown]
# $\quad$ Este fractal obtido acima é de ordem 4. Ou seja, repetimos o processo de dividir cada linha em três e adicionar dois lados de um triângulo nela 4 vezes. Se continuarmos a aumentar a ordem, podemos observar que as bordas ficam cada vez mais tortuosas. No entanto, a área do floco de neve continua contida dentro da forma aproximada de um hexágono. Veremos a seguir que isso implica em uma propriedade bastante interessante deste fractal! (**NOTA:** a biblioteca ```turtle```do python não consegue formar imagens diretamente no notebook, ela abre outra página para rodar. Tanto a imagem acima quanto a próxima imagem foram capturas de tela desta outra janela.)

# %%
def draw_flake2():
    speed(0)
    up()
    backward(200 / 2.0)
    down()
    color('black')
    fillcolor('white')
    begin_fill()
    for i in range(3):
        koch_flake(300.0, 5) #vamos colocar uma ordem maior!
        left(-120)
    end_fill()
    mainloop()
    
draw_flake2()

# %% [markdown]
# ![Captura de tela 2026-05-15 001145.png](attachment:9f85b5bb-63df-46ba-8a9c-439e35a86b0d.png)

# %% [markdown]
# ## 4. Área vs Perímetro

# %% [markdown]
# $\quad$ Uma propriedade muito interessante do floco de neve Koch é a crescente diferença entre os valores da sua _área_ e de seu _perímetro_. Vamos analisar nosso floco para primeiro encontrar sua área: Inicialmente, o triângulo possui 3 lados, cada um com comprimento de uma unidade. Na próxima iteração, há 12 lados, cada um com comprimento de 1/3 de unidade (cada um dos três lados retos do triângulo é substituído por quatro novos segmentos). Na iteração seguinte, há 48 lados, cada um com comprimento de 1/9 de unidade (cada uma das 12 arestas anteriores é substituída por quatro novos segmentos).
# A cada nível mais profundo, criamos quatro vezes mais lados do que no nível anterio
#
# Agora que sabemos disso, vamos ver como a área se altera a cada nova iteração. Iniciando com o triângulo equilátero, sabemos que sua área pode ser calculada de acordo com a expressão $A=\frac{\sqrt{3}}{4}s^2$.
#
# ![Captura de tela 2026-05-14 233407.png](attachment:25f01fe2-b48b-4e7a-82cb-d49baecc85f1.png)
#
# Assim sendo, podemos concluir que o triângulo original terá a seguinte área:
# $$A_0=\frac{\sqrt{3}}{4}s^2.$$
#
# Na próxima iteração, a área do floco de neve é ​​aumentada pelos três triângulos vermelhos mostrados no diagrama abaixo
# (Três novos triângulos com lados de comprimento$s/3$3)
#
# ![Captura de tela 2026-05-14 234029.png](attachment:4e4723fb-9c61-4c2d-9a98-d6f48bf2a5da.png)
#
# Assim, ficaremos com uma área total de
#
# $$A_1=\frac{\sqrt{3}}{4}s^2+3\left(\frac{\sqrt{3}}{4}\left(\frac{s}{3}\right)^2\right).$$
#
# Na próxima iteração, adicionamos mais 12 triângulos menores. A área de cada um desses novos triângulos é somada à área total:
#
# ![Captura de tela 2026-05-14 234359.png](attachment:274a48a0-5712-4087-b8eb-dd545cc032b5.png)
#
# $$A_1=\frac{\sqrt{3}}{4}s^2+3\left(\frac{\sqrt{3}}{4}\left(\frac{s}{3}\right)^2\right)+12\left(\frac{\sqrt{3}}{4}\left(\frac{s}{9}\right)^2\right).$$
#
# E assim por diante! Podemos concluir que nossa área total para $n$ iterações é dada por uma somatória.
#
# $$A_n=\frac{\sqrt{3}s^2}{16}\left[4 + 3\left(\frac{4}{9}\right)+ 3\left(\frac{4}{9}\right)^2 + 3\left(\frac{4}{9}\right)^3 + ... + 3\left(\frac{4}{9}\right)^n\right]$$
#
# Vamos agora dizer que a nossa série infinita se chama $G$.
#
# $$A_n=\frac{\sqrt{3}s^2}{16}[4 + G]$$
# $$G=3\left[\frac{4}{9}+ \left(\frac{4}{9}\right)^2 + \left(\frac{4}{9}\right)^3 + ... + \left(\frac{4}{9}\right)^n\right]$$
#
# Agora, vamos usar um truque! Sabendo $G$, conseguimos descobrir $\frac{4}{9}G$ também, apenas fazendo uma multiplicação:
#
# $$\frac{4}{9}G=3\left[\left(\frac{4}{9}\right)^2 + \left(\frac{4}{9}\right)^3 + ... + \left(\frac{4}{9}\right)^n\right]$$
#
# Fazendo $G-\frac{4}{9}G$, podemos perceber que todos os termos (menos o primeiro!) se cancelam:
# $$G - \frac{4}{9}G = 3\left(\frac{4}{9}+ \left(\frac{4}{9}\right)^2 + \left(\frac{4}{9}\right)^3 + ... + \left(\frac{4}{9}\right)^n\right) - 3\left(\left(\frac{4}{9}\right)^2 + \left(\frac{4}{9}\right)^3 + ... + \left(\frac{4}{9}\right)^n\right)$$
# $$\frac{5}{9}G= 3\left(\frac{4}{9}\right)$$
# $$G = \frac{12}{5}$$
#
# Assim, podemos usar o valor que encontramos para $G$ para encontrar nosso valor para $A_n$:
#
# $$A_n=\frac{\sqrt{3}s^2}{16}\left(4 + G\right)$$
# $$A_n=\frac{\sqrt{3}s^2}{16}\left(4 + \frac{12}{5}\right)$$
# $$A_n=\frac{\sqrt{3}s^2}{16}\left(\frac{32}{5}\right)$$
# $$A_n=\frac{2\sqrt{3}s^2}{5}$$
#
# Quando $n$ tende a infinito, é possível perceber que a área final do floco de neve será exatamente igual a $\frac{8}{5}$ da área inicial do triângulo.

# %% [markdown]
# Mas e quanto ao perímetro, como ele evolui com o número de iterações?
#
# A cada passo que damos, o comprimento de cada lado é substituído por quatro conjuntos de comprimentos que correspondem a um terço do comprimento anterior. Aqui está a equação simples para o comprimento dos lados em cada profundidade:
#
# $$L_n=3\left(\frac{4}{3}\right)^n$$
#
# Quando $n$ tende ao infinito, a fração explode e nos mostra que $L$ também tende ao infinito:
#
# $$\lim_{n \to \infty}L_n=\lim_{n \to \infty}3\left(\frac{4}{3}\right)^n=\infty$$
#
# Ou seja, o floco de neve Koch de infinitas iterações possui uma **área finita** mas um **perímetro infinito**! Isso parece ir contra o nosso senso comum, mas mostra como fractais conseguem ser tão intrigantes e se manter objeto de estudo de vários pesquisadores até os dias de hoje. Podemos visualizar melhor a diferença entre a área e o perímetro de acordo com o número de iterações através do gráfico abaixo:

# %%
n = np.arange(0, 15)

#assumimos área inicial (A_0) = 1 e Perímetro inicial (P_0) = 3
area = (8/5) - (3/5) * (4/9)**n
perimetro = 3 * (4/3)**n

fig, ax1 = plt.subplots(figsize=(11, 6), dpi=100)

#configurando o eixo da esquerda (Área)
color_area = '#467BBD'
ax1.set_xlabel('Geração (n)', fontsize=12)
ax1.set_ylabel('Área Total', color=color_area, fontsize=12, fontweight='bold')
plot_area = ax1.plot(n, area, color=color_area, marker='o', linewidth=2.5, label='Área (Converge para 1.6)')
ax1.tick_params(axis='y', labelcolor=color_area)
ax1.set_ylim(0.8, 2.0) #escala curta para destacar a estabilização

#adicionando uma linha tracejada para mostrar o limite de convergência de 1.6
plt.axhline(y=1.6, color='#666666', linestyle='--', linewidth=1.5, label='Limite de Convergência (1.6)')

#criando o eixo da direita (Perímetro)
ax2 = ax1.twinx() 
color_perim = '#B94441'
ax2.set_ylabel('Perímetro Total', color=color_perim, fontsize=12, fontweight='bold')
plot_perim = ax2.plot(n, perimetro, color=color_perim, marker='s', linewidth=2.5, label='Perímetro (Tende ao Infinito)')
ax2.tick_params(axis='y', labelcolor=color_perim)
ax2.set_ylim(0, 100) #escala longa para o crescimento exponencial

plt.title('O Paradoxo de Koch: Área Finita vs Perímetro Infinito', fontsize=15, pad=20)
ax1.grid(True, linestyle='--', alpha=0.6)

# Combinando as legendas de ambos os eixos em uma só
lns = plot_area + plot_perim
labs = [l.get_label() for l in lns]
ax1.legend(lns, labs, loc='upper left', frameon=True, shadow=True)

fig.tight_layout()
plt.show()

# %% [markdown]
# ## 5. Conclusão

# %% [markdown]
# $\quad$ Posto tudo isso, podemos perceber o quão interessante é o mundo dos fractais. E este ```Notebook``` busca analisar apenas um deles! Ao procurarmos descobrir as propriedades dessas intrincadas figuras, nos deparamos com curiosidades fantásticas e às vezes difíceis de compreender, mas muito fascinantes.
#
# $\quad$ Hoje em dia, por causa de sua propriedade de área finita e perímetro infinito, algumas das aplicações específicas do floco de neve Koch são em engenharia de antenas compactas, maximizando o perímetro do material que transmite ou recebe radiação eletromagnética porém mantendo a possibilidade de encaixe em circuitos complexos; em engenharia acústica, onde uma metassuperfície acústica inspirada em seu formato foi testada para difusão sonora de banda larga em cabines automotivas; e na física térmica para aumentar fluxo de calor em _double pipe heat exchangers_.

# %% [markdown]
# ## Referências

# %% [markdown]
# [1] DataGenetics. Koch Snowflake. http://datagenetics.com/blog/january12016/index.html
#
# [2] Lakshmi, Godha. A simple introduction to the world of fractals using python. https://godhalakshmi.medium.com/a-simple-introduction-to-the-world-of-fractals-using-python-c8cb859bfd6d
#
# [3] Mr. Reid. Fixed Area, Infinite Perimeter. http://wordpress.mrreid.org/2015/10/05/fixed-area-infinite-perimeter/
#
# [4] Wikipedia. Koch Snowflake. https://en.wikipedia.org/wiki/Koch_snowflake
#
# [5] Wikipedia. L-system. https://en.wikipedia.org/wiki/L-system
#
# [6] Wikipedia. Fractal. https://en.wikipedia.org/wiki/Fractal
#
# [7] Wikipedia. Fractal dimension. https://en.wikipedia.org/wiki/Fractal_dimension
#
# [8] Wikipedia. Iterated function system. https://en.wikipedia.org/wiki/Iterated_function_system
