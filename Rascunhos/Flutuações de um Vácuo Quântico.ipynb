# %% [markdown]
# # Flutuações de um Vácuo Quântico
#
# * PET Física - UFRN
# * Petiano: Wallysson Pereira da Silva
# * Data: 01/05/2026
#
# $\quad$ Neste projeto estaremos utilizando um resultado bem interessante da Teoria Quântica de Campos para simular o comportamento do vácuo. Como será desenvolvido mais adiante, esse resultado nos indica que o vácuo não é totalmente isento de energia, ainda há pequenas flutuações, que visualizaremos através de plots. Com isso em mente, esse `Notebook` foi dividido nas seguintes seções
#
#     1. Introdução Teórica;
#     2. Visualização estática;
#     3. Evolução temporal;
#     4. Função de Correlação;
#     5. Evolução Simultânea;
#     6. Conclusão.

# %% [markdown]
# ## Importando bibliotecas

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %% [markdown]
# ## Informações sobre as bibliotecas

# %%
# %load_ext version_information
# %version_information Matplotlib, Numpy
# Out:
# Software versions
# Python 3.13.0 64bit [MSC v.1941 64 bit (AMD64)]
# IPython 8.29.0
# OS Windows 11 10.0.26200 SP0
# Matplotlib 3.9.2
# Numpy 2.1.3
# Wed Apr 29 01:23:56 2026 Hora Padrão de Buenos Aires

# %% [markdown]
# ## 1. Introdução Teórica
#
# $\quad$ A existência do vácuo sempre foi uma questão filosófica bem relevante em diversas sociedades. Na própria cultura grega, relacionava-se a ideia de vácuo — entendida como a ausência total de matéria — com a existência do movimento. Dentro do mundo grego antigo, apesar das divergências entre os ditos eleatas e os atomistas sobre a existência ou não do vácuo, ambos concordavam que, se ele existesse, o movimento existiria. Mais tarde, Aristóteles estabeleceu que a natureza tenderia naturalmente a preencher os espaços vazios que surgissem, logo impossibilitando a existência do vácuo **[1]**.
#
# $\quad$ A noção cotidiana atual sobre o tema, isto é, a de ausência absoluta de matéria e energia, alinha-se perfeitamente à interpretação da física clássica. Assim, imaginamos que seria possível pegar uma caixa, retirar todas as partículas, isolá-la completamente do ambiente externo, restando tão somente o absoluto nada em seu interior. No entanto, a Teoria Quântica de Campos (QFT) demonstrou de maneira satisfatória que essa visão está incompleta. O vácuo não é apenas um palco vazio, mas sim um meio com rica dinâmica **[2]**. Neste trabalho, simularemos o comportamento do campo escalar de Klein-Gordon, o modelo mais simples da teoria de campos.
#
# $\quad$ Dentro do contexto do campo escalar de Klein-Gordon, buscaremos simular o estado de menor energia possível: o estado de vácuo. Para tal, é importante destacar que a QFT abandona a ideia de um universo feito de entidades físicas isoladas, ao passo que eleva o campo ao patamar de bloco fundamental da natureza. Pense num campo como uma entidade que permeia todo o espaço (e o tempo) de forma contínua por toda a sua extensão. O exemplo mais comum seria o de um campo de temperatura.
#
# $\quad$ Nesse contexto de campos permeando todo o espaço, o que nós antes conhecíamos como "partícula", agora é apenas uma ondulação ou excitação empacotada viajando através desse campo. Sob esse paradigma, poderíamos pensar que o vácuo seria representado por um campo totalmente plano e imóvel, com energia zero. No entanto, fazendo jus à parte "quântica" da QFT, o Princípio da Incerteza de Heisenberg proíbe essa imobilidade absoluta. Assim como não podemos saber a posição e a velocidade de um elétron ao mesmo tempo, não podemos fixar o valor do campo e sua taxa de variação simultaneamente. Como resultado, o campo sofre oscilações probabilísticas contínuas, criando minúsculas ondas de energia que aparecem e desaparecem quase instantaneamente. Essas são as chamadas flutuações de vácuo, existintes por causa da criação e aniquilação de inúmeras partículas virtuais **[2]**.
#
# $\quad$ Para simular esse mar quântico computacionalmente, recorremos à matemática da quantização canônica. Nesse paradigma, o campo clássico $\phi(x)$ e sua densidade de momento conjugado $\Pi(x)$ são promovidos a operadores fundamentais: $\phi(x) \to \hat{\phi}(x)$ e $\Pi(x) \to \hat{\Pi}(x)$. A quantização ocorre ao impormos relações de comutação não nulas entre esses entes. Por exemplo, avaliando os campos em um mesmo instante de tempo $t$, exige-se que $[\hat{\phi}(t,\textbf{x}), \hat{\Pi}(t,\textbf{y})] = i\delta^{(3)}(\textbf{x}-\textbf{y})$. Fisicamente, isso significa que não podemos medir o valor do campo e sua taxa de variação simultaneamente com precisão absoluta. Como detalhado na referência **[2]**, a consequência mais profunda dessa quantização é que o campo, nesse caso real, pode ser decomposto em uma expansão de modos de Fourier, expressa em termos de operadores de criação ($\hat{a}^\dagger$) e aniquilação ($\hat{a}$):
#
# $$\hat{\phi}(x) = \int \frac{d^{d}p}{(2\pi)^{\frac{d}{2}}}\frac{1}{\sqrt{2\omega_p}}\left(\hat{a}_p e^{i\textbf{p}\cdot \textbf{x}} + \hat{a}_{p}^{\dagger} e^{-i\textbf{p}\cdot \textbf{x}}\right),$$
#
# onde $d$ é a dimensionalidade espacial e, por adotarmos o sistema de unidades naturais ($\hbar = c = 1$), a frequência $\omega_p$ equivale numericamente à energia $E_p$. Conceitualmente, essa equação é belíssima: ela nos revela que o campo quântico é matematicamente equivalente a um conjunto infinito de osciladores harmônicos permeando todo o espaço, onde cada modo de momento $\mathbf{p}$ vibra de forma independente com sua própria frequência $\omega_p$.
#
# $\quad$ Tendo estabelecido que o campo atua como uma infinidade de osciladores, precisamos definir qual é a base energética desse sistema. Sabemos que o operador de aniquilação $\hat{a}_p$ atua exatamente removendo um "quantum" de energia $\omega_p$ do modo de oscilação $\mathbf{p}$. Para que a física faça sentido e a energia do universo não decaia infinitamente para valores negativos (o que geraria instabilidades catastróficas), deve existir obrigatoriamente um patamar de energia mínima. Chamamos esse estado fundamental de vácuo, denotado por $|0\rangle$, e ele é definido pela condição absoluta de que não há mais energia a ser retirada: $\hat{a}_p|0\rangle = 0$ para qualquer $\mathbf{p}$. Como a referência **[2]** ilustra de forma didática, ao resolvermos essa exata condição para um único oscilador harmônico na mecânica quântica convencional, obtemos uma função de onda gaussiana para o seu estado fundamental. Estendendo esse resultado lógico: como o campo livre é constituído por osciladores independentes, o estado do vácuo total será simplesmente o produto infinito de todos esses estados gaussianos individuais. Ao expressarmos isso no contínuo, obtemos a forma exata do estado fundamental (conhecido como funcional de onda do vácuo):
#
# $$\langle \phi | 0 \rangle = \Psi_0[\phi] = \mathcal{N}\exp{\left(-\frac{1}{2}\int d^{3}p \ \omega_p |\phi_p|^2\right)}, \tag{1}$$
#
# sendo $\mathcal{N}$ uma constante de normalização. Essa expressão final revela a característica mais importante para a nossa modelagem computacional: a distribuição das flutuações do campo no vácuo possui um comportamento puramente gaussiano.
#
# $\quad$ Partindo para a interpretação estatística desse estado, a probabilidade de encontrarmos o vácuo flutuando em uma determinada configuração de campo $\phi$ é dada pelo módulo quadrado do seu funcional de onda ($|\Psi_0[\phi]|^2$). Assim, a densidade de probabilidade assume a forma:
#
# $$\mathcal{P}[\phi] \propto \exp{\left( -\int d^{3}p \ \omega_p |\phi_p|^2\right)}.$$
#
# $\quad$ Ao observarmos essa expressão sob a ótica da estatística, notamos que ela descreve justamente o produto contínuo daquelas infinitas distribuições normais independentes, uma para cada modo de momento $\mathbf{p}$. Comparando o argumento da exponencial com a forma de uma gaussiana padrão ($e^{-x^2 / 2\sigma^2}$), concluímos diretamente que a variância $\sigma_p^2$ para um dado modo $\mathbf{p}$ é inversamente proporcional à sua frequência (ou energia), isto é, $\sigma_p^2 \propto \frac{1}{\omega_p}$. Fisicamente, isso nos revela um mecanismo de regulação natural do universo: as flutuações de alta energia (modos curtos) são severamente suprimidas por terem uma variância minúscula, enquanto os modos de baixa energia (ondas longas) oscilam com maior amplitude e liberdade.
#
# $\quad$ É exatamente essa bela conclusão estatística que nos fornece a "receita" fundamental para construir o nosso universo numérico. Se o vácuo quântico é matematicamente regido por um conjunto de distribuições gaussianas com variâncias perfeitamente conhecidas ($\propto 1/\omega_p$), podemos simular a sua manifestação física sorteando números aleatórios no computador que obedeçam a essa exata regra. Na próxima seção, deixaremos o formalismo analítico e construiremos um código para simular o comportamento do vácuo. Começaremos gerando um "instantâneo" congelado no tempo desse campo, traduzindo a abstração matemática que acabamos de derivar em uma matriz bidimensional de ruído quântico fisicamente calibrado.

# %% [markdown]
# ## 2. Visualização estática
#
# $\quad$ Utilizando o ferramental teórico desenvolvido anteriormente, partiremos agora para a simulação computacional. Primeiramente, definiremos as constantes que regem o nosso ambiente simulado.

# %%
# Parâmetros da Simulação
N = 512        # Tamanho da grade (512x512 pixels).
L = 10.0       # Tamanho físico da nossa grade.
m = 0.5        # Massa da partícula do campo.

# %% [markdown]
# $\quad$ Na física analítica, o espaço é contínuo e infinito. No computador, entretanto, precisamos de uma grade finita e discreta. A função `np.fft.fftfreq` que utilizaremos determina as frequências espaciais permitidas nessa nossa grade de tamanho $N \times N$. Fisicamente, estamos definindo todos os vetores de onda $\vec{k}$ (ou momentos, já que adotamos o sistema de unidades naturais onde $\hbar=1$) possíveis que cabem na nossa "caixa" de simulação de dimensão $L$. A função `np.meshgrid` cruza essas frequências para criar um plano 2D de momentos, permitindo analisar ondas propagando-se em qualquer direção.

# %%
# Aqui definimos as frequências (ondas) possíveis na nossa grade.
kx = np.fft.fftfreq(N, d=L/N) * 2 * np.pi
ky = np.fft.fftfreq(N, d=L/N) * 2 * np.pi
KX, KY = np.meshgrid(kx, ky)

# %% [markdown]
# $\quad$ Em seguida, calcularemos a energia associada a cada modo do campo. A expressão a seguir é a implementação computacional direta da relação de dispersão da relatividade restrita (com $c=1$):
#
# $$\omega_k = \sqrt{|\vec{k}|^2 + m^2}.$$
#
# $\quad$ Para cada ponto no nosso espaço de momentos (representando uma onda específica), calculamos o seu respectivo custo energético $\omega_k$. O termo de massa $m$ garante que até as ondas de momento zero possuam uma energia mínima, o que modela corretamente um campo massivo e previne divisões por zero nas próximas etapas.

# %%
# Implimentação da relação de dispersão.
omega_k = np.sqrt(KX**2 + KY**2 + m**2)

# %% [markdown]
# $\quad$ Conforme demonstrado analiticamente na referência **[2]**, o estado do vácuo quântico é ditado por um funcional de probabilidade estritamente gaussiano. A função `np.random.normal(0, 1)` reflete matematicamente essa propriedade no nosso código. Como os operadores $\hat{a}$ e $\hat{a}^\dagger$ não comutam, o valor do campo não é estático, flutuando aleatoriamente em torno do zero. Construímos um ruído branco complexo sorteando valores de uma distribuição normal para simular o comportamento probabilístico desses operadores para cada frequência isolada do nosso universo. Note que, computacionalmente, geraremos apenas uma variável aleatória complexa (`a_k`) associada ao operador de aniquilação. Isso ocorre porque o campo escalar físico é real (hermitiano); logo, os graus de liberdade do operador de criação já estão intrinsecamente definidos, correspondendo simplesmente ao complexo conjugado da matriz sorteada ($a_k^*$).

# %%
# Simulamos os operadores de criação/aniquilação como números complexos aleatórios. Eles seguem uma distribuição normal (Gaussiana).
ruido_real = np.random.normal(0, 1, (N, N))
ruido_imag = np.random.normal(0, 1, (N, N))
a_k = (ruido_real + 1j * ruido_imag) / np.sqrt(2)

# %% [markdown]
# $\quad$ Com os nossos "operadores" probabilísticos $a_k$ devidamente sorteados, precisamos conectá-los de volta à equação principal do campo. Se olharmos para a nossa expansão de Fourier teórica, notaremos que o operador de aniquilação não atua sozinho dentro da integral. Esta próxima etapa computacional representa a essência dessa quantização: a amplitude do campo no espaço das frequências (que chamaremos de $\phi_k$) é dada pela modulação do operador pela energia do seu respectivo modo. Implementaremos, portanto, a seguinte relação diretamente tirada da nossa expansão:
#
# $$\phi_k = \frac{a_k}{\sqrt{2\omega_k}}.$$
#
# $\quad$ É crucial entender que, como o valor médio do campo no vácuo é zero ($\langle 0 | \hat{\phi} | 0 \rangle = 0$)**[2]**, o próprio campo **é** a flutuação. Ao dividirmos o nosso ruído quântico puramente aleatório pela raiz da energia da respectiva onda, impomos uma restrição física severa: ondas de alta frequência (alta energia) flutuam com amplitudes minúsculas, enquanto ondas de baixa frequência flutuam de forma muito mais expressiva. É essa modulação que transforma um simples ruído branco computacional na textura física autêntica de um campo quântico.

# %%
# Definição do campo no espaços dos momentos.
phi_k = a_k / np.sqrt(2 * omega_k)

# %% [markdown]
# $\quad$ Até a etapa anterior, o campo simulado estava descrito inteiramente no espaço das frequências (momentos). A Transformada Inversa Rápida de Fourier 2D (`np.fft.ifft2`) realiza a integral responsável por somar todas essas infinitas ondas $\phi_k$, cada uma com sua fase e amplitude corretas, mapeando-as de volta para o espaço real. Como o campo escalar de Klein-Gordon descreve partículas neutras, o campo físico resultante deve ser estritamente real (um operador Hermitiano). Desse modo, extrairemos apenas a parte real (`np.real`) para descartar resíduos numéricos imaginários ínfimos advindos de erros de precisão de ponto flutuante da máquina.

# %%
# Pegamos as ondas no espaço dos momentos e transformamos no campo físico no espaço real.
phi_x = np.fft.ifft2(phi_k)

# O campo escalar físico é a parte real do resultado.
campo_fisico = np.real(phi_x)

# %% [markdown]
# $\quad$ Esta etapa final converte a matriz espacial resultante em uma representação visual bidimensional. O gráfico ilustra a distribuição espacial das amplitudes do campo escalar real $\phi(x, y)$, destacando geometricamente as regiões de picos (valores positivos) e vales (valores negativos). O resultado é um "instantâneo" do estado fundamental $|0\rangle$, permitindo observar de forma tangível como as flutuações de ponto zero — desde as de alta frequência e baixa amplitude até as ondas espaciais mais longas — se distribuem e interagem no espaço simulado.

# %%
# Visualização do Vácuo (Campo Escalar).
plt.figure(figsize=(6, 6))
plt.imshow(campo_fisico, cmap='magma', extent=[0, L, 0, L])
plt.colorbar(label='Amplitude da Flutuação do Vácuo')
plt.title('Simulação 2D do Vácuo Quântico')
plt.xlabel('Coordenada X')
plt.ylabel('Coordenada Y')
plt.show()

# %% [markdown]
# ## 3. Função de Correlação
#
# $\quad$ Na física clássica, o "vácuo" é o nada absoluto. Se o campo é zero em um ponto, ele também é zero no ponto ao lado; não há correlação porque não há nada lá. No entanto, como já demonstrado, a QFT estabelece um comportamento probabilístico para as flutuações do campo. Desse modo, entende-se que o estado fundamental (o nível de menor energia possível, que chamamos de vácuo) ferve constantemente com partículas e antipartículas virtuais surgindo e desaparecendo — as chamadas flutuações de ponto zero **[2]**. Embora a média global do campo seja zero ($\langle \phi \rangle = 0$), essas flutuações não ocorrem de forma isolada. Quando uma flutuação virtual surge no vácuo, sua influência se espalha pelo espaço ao seu redor antes de desaparecer **[3]**. Isso significa que o vácuo possui uma "textura" espacial; regiões próximas estão intrinsecamente emaranhadas e influenciam umas às outras. Nesse contexto, é natural esperar uma correlação: se medirmos uma flutuação quântica no ponto $\mathbf{x}$, qual é o grau de dependência estatística e a influência que ela exerce sobre um ponto vizinho $\mathbf{y}$?
#
# $\quad$ Matematicamente, essa influência mútua entre os pontos da nossa grade é chamada de autocorrelação. Considerando o estado fundamental, a correlação do campo $\phi$ nos pontos $\mathbf{x}$ e $\mathbf{x}+\mathbf{r}$ é formalmente denotada pelo valor esperado $\langle 0 | \phi(\mathbf{x})\phi(\mathbf{x}+\mathbf{r}) | 0 \rangle$ **[2]**. Na Teoria Quântica de Campos, essa mesma métrica recebe o nome de Função de Correlação de Dois Pontos a Tempos Iguais, ou simplesmente Propagador Espacial **[2]**. Como assumimos que o vácuo é homogêneo e isotrópico (invariante sob translações e rotações), podemos escolher um local qualquer para calcular sua correlação com o restante da grade. Por conveniência, adota-se $\mathbf{x} = \mathbf{0}$ (a origem) e considera-se $\mathbf{r}$ como o vetor distância de um ponto genérico até essa origem, reduzindo a expressão para $\langle 0 | \phi(\mathbf{0})\phi(\mathbf{r}) | 0 \rangle$.
#
# $\quad$ Computacionalmente, calcular essa correlação espacial varrendo a grade bidimensional pixel por pixel exigiria um esforço numérico gigantesco, com uma complexidade de tempo na ordem de $\mathcal{O}(N^4)$. Para viabilizar a simulação de forma eficiente, recorremos a um atalho poderoso do processamento de sinais: o Teorema de Wiener-Khinchin **[4]**. Este teorema estabelece que, para processos aleatórios espacialmente estacionários — como é o caso do vácuo quântico homogêneo —, a função de autocorrelação no espaço real (ou seja, no domínio das coordenadas e distâncias físicas tangíveis $\mathbf{r}$ da nossa grade) é simplesmente a Transformada de Fourier do espectro de potência do sinal, que está descrito no espaço dos momentos (o domínio abstrato das frequências e vetores de onda $\mathbf{k}$). Essa abordagem, implementada através da Transformada Rápida de Fourier (FFT), reduz drasticamente a complexidade computacional para $\mathcal{O}(N^2 \log N)$**[5]**.
#
# $\quad$ Lembrando que a amplitude computacional de cada modo do campo no espaço dos momentos é modulada por $1/\sqrt{\omega_k}$, o espectro de potência (que é o módulo quadrado da amplitude) torna-se estritamente proporcional a $1/\omega_k$. A matemática canônica confirma esse atalho, mostrando que a correlação espacial das posições físicas é calculada exatamente pela integral que mapeia os momentos de volta para o espaço real:
#
# $$\langle 0 | \phi(\mathbf{0})\phi(\mathbf{r}) | 0 \rangle \propto \int \frac{d^2 k}{(2\pi)^2} \frac{1}{\sqrt{|\mathbf{k}|^2 + m^2}} e^{i \mathbf{k} \cdot \mathbf{r}},$$
#
# onde a relação de dispersão relativística nos garante exatamente que a energia obedece à equação $\omega_k = \sqrt{|\mathbf{k}|^2 + m^2}$. Com esse resultado analítico perfeitamente alinhado com a teoria de sinais, construiremos na próxima etapa o código que calcula e exibe a autocorrelação do vácuo através de um mapa de calor.

# %% [markdown]
# ### 3.1 Autocorrelação 2D (Heatmap)
#
# $\quad$ Conforme introduzido anteriormente, o Teorema de Wiener-Khinchin estabelece uma relação direta entre o espectro de potência no espaço dos momentos e a autocorrelação no espaço real. Assim, utilizaremos a Transformada Inversa de Fourier para trazer essa informação de volta para o domínio das posições físicas.
#
# $\quad$ Para este passo, utilizaremos a configuração do campo no espaço dos momentos (`phi_k`), que já foi previamente gerada. Como o teorema afirma que a autocorrelação espacial é a Transformada de Fourier do espectro de potência, calculamos inicialmente esse espectro tomando o módulo quadrado da amplitude, $|\phi(\mathbf{k})|^2$. Em seguida, aplicamos a Transformada Inversa de Fourier para obter a matriz de autocorrelação bidimensional.

# %%
# O espectro de potência é o módulo ao quadrado do campo no espaço dos momentos.
espectro_potencia = np.abs(phi_k)**2
# Zeramos o componente de frequência zero (k=0) para remover o "fundo constante" e evitar que um pico massivo ofusque as correlações locais no plot.
espectro_potencia[0, 0] = 0 
# A autocorrelação é a Transformada Inversa de Fourier do espectro de potência.
autocorr_2d = np.real(np.fft.ifft2(espectro_potencia))
#Deslocamos a frequência zero para o centro da matriz para facilitar a visualização.
autocorr_2d = np.fft.fftshift(autocorr_2d)

# %% [markdown]
# $\quad$ Com essas operações, já possuímos os dados numéricos correspondentes à autocorrelação espacial do nosso campo simulado. O bloco de código a seguir gera o mapa de calor para visualizarmos a intensidade dessa influência mútua entre os pontos.

# %%
# Plot Mapa de Calor da Autocorrelação.
plt.figure(figsize=(6, 6), dpi = 90)

# Usamos um percentil para cortar o pico extremo central (r=0) e melhorar o contraste visual das correlações vizinhas. 
vmax_corte = np.percentile(autocorr_2d, 98)
plt.imshow(
    autocorr_2d,
    cmap='viridis',
    extent=[-L/2, L/2, -L/2, L/2],
    origin='lower',
    vmax=vmax_corte
)

plt.title('Autocorrelação 2D do Vácuo')
plt.xlabel(r'Distância $\Delta x$')
plt.ylabel(r'Distância $\Delta y$')
plt.colorbar(label='Força da Correlação')
plt.show()

# %% [markdown]
# $\quad$ A teoria estabelece que o valor esperado da autocorrelação, $\langle 0 | \phi(\mathbf{0})\phi(\mathbf{r}) | 0 \rangle$, deve ser perfeitamente isotrópico (possuir simetria de rotação), dependendo unicamente da distância absoluta $|\mathbf{r}|$ em relação à origem. Visualmente, entretanto, não é isso que observamos no gráfico recém-gerado, que costuma apresentar um padrão um tanto irregular e granulado.
#
# $\quad$ A explicação para essa aparente discrepância reside no significado físico de "valor esperado". O valor esperado representa a média estatística calculada sobre infinitas configurações possíveis do campo. No entanto, ao definirmos o nosso estado através da distribuição normal, nós sorteamos aleatoriamente apenas uma única configuração (um único "microestado") do vácuo. Como a mecânica quântica é fundamentalmente probabilística, essa única amostra carrega consigo flutuações estatísticas severas (ruído) ao redor da média teórica.
#
# $\quad$ Nesse contexto, o gráfico acima reproduz a autocorrelação intrínseca de apenas uma configuração estática isolada. Para recuperarmos o comportamento isotrópico e suave previsto pela teoria, precisaríamos simular um número massivo de configurações independentes do vácuo e calcular a média entre todos os mapas de correlação. A próxima seção deste trabalho lidará exatamente com a construção dessa amostra estatística.

# %% [markdown]
# ### 3.2 Simulando Múltiplos Vácuos
#
# $\quad$ Com o objetivo de recuperar o comportamento teórico médio da autocorrelação do vácuo, simularemos uma amostra estatística de 1000 configurações (vácuos independentes). O procedimento consistirá em calcular o espectro de potência de cada configuração gerada e somá-lo a um acumulador. Ao final do laço de repetição, dividiremos essa soma pelo número total de simulações, obtendo assim o espectro de potência médio.

# %%
num_simulacoes = 1000

# Matriz que começará com zeros e acumulará a soma dos espectros de cada simulação.
soma_espectro = np.zeros((N, N))

# Loop para calcular a média estatística do espectro de potências do vácuo.
for i in range(num_simulacoes):
    # Gera o ruído quântico aleatório para um universo específico.
    ruido_real = np.random.normal(0, 1, (N, N))
    ruido_imag = np.random.normal(0, 1, (N, N))
    a_k = (ruido_real + 1j * ruido_imag) / np.sqrt(2)
    
    # Aplica a modulação da energia (Equação do Campo no espaço dos momentos).
    phi_k = a_k / np.sqrt(2 * omega_k)
    
    # Calcula o espectro de potência deste universo específico.
    espectro_potencia = np.abs(phi_k)**2
    
    # Adiciona o resultado à matriz acumuladora.
    soma_espectro += espectro_potencia

# %% [markdown]
# $\quad$ Com a soma de todos os microestados concluída, calculamos a média dividindo pelo número de simulações. Em seguida, de maneira análoga à seção anterior, aplicamos a Transformada Inversa de Fourier neste espectro médio limpo para resgatar a matriz de autocorrelação espacial esperada para o estado fundamental.

# %%
# Tira a média de todas as simulações executadas.
espectro_medio = soma_espectro / num_simulacoes

# Remove o modo zero (a média global do campo) para evitar ofuscamento do gráfico.
espectro_medio[0, 0] = 0 

# Aplica a IFFT no espectro médio para voltar ao espaço real das posições.
autocorr_2d_amostra = np.real(np.fft.ifft2(espectro_medio))

# Centraliza a frequência zero no meio da grade.
autocorr_2d_amostra = np.fft.fftshift(autocorr_2d_amostra)

# %% [markdown]
# $\quad$ O último passo desta etapa é a visualização gráfica da matriz resultante. Como agora possuímos uma amostragem estatística robusta, esperamos que o ruído aleatório tenha se cancelado mutuamente, revelando a verdadeira estrutura espacial das flutuações.

# %%
# Plot Mapa de calor da Autocorrelação Espacial (amostra estatística).
plt.figure(figsize=(6, 6))

# Usa um percentil para não deixar o pico central ofuscar as bordas mais suaves.
vmax_corte = np.percentile(autocorr_2d_amostra, 98)

plt.imshow(
    autocorr_2d_amostra,
    cmap='viridis',
    extent=[-L/2, L/2, -L/2, L/2],
    vmax=vmax_corte
)

plt.title(f'Autocorrelação 2D do Vácuo\n(Média da Amostra: {num_simulacoes} simulações)')
plt.xlabel(r'Distância $\Delta x$')
plt.ylabel(r'Distância $\Delta y$')
plt.colorbar(label='Força da Correlação')

plt.show()

# %% [markdown]
# $\quad$ Desta vez, observamos claramente o resgate do comportamento isotrópico previsto pela teoria analítica. O gráfico exibe uma simetria perfeitamente circular a partir do centro (a origem $\mathbf{r} = \mathbf{0}$), demonstrando que a força da influência mútua entre dois pontos no vácuo independe da direção, com a sua intensidade decaindo suavemente e de forma uniforme à medida que a distância espacial entre eles aumenta.
#
# $\quad$ Embora o mapa de calor nos forneça uma excelente confirmação qualitativa e visual dessa isotropia, o verdadeiro teste da nossa simulação reside na análise quantitativa desse decaimento. Já que a correlação demonstrou depender apenas da distância radial, podemos achatar essas informações bidimensionais em um gráfico unidimensional, revelando exatamente como a força dessa influência decai à medida que nos afastamos da origem. É essa extração de dados e a sua posterior comparação com a rigorosa previsão analítica da Teoria Quântica de Campos que executaremos na próxima seção.

# %% [markdown]
# ### 3.3 Correlação Radial vs Teoria
#
# $\quad$ Tendo estabelecido visualmente o comportamento isotrópico do vácuo, o próximo passo lógico é focar na evolução estritamente radial da autocorrelação. Neste ponto, é essencial introduzir um resultado analítico fundamental da QFT: para um campo escalar livre, a correlação espacial decai assintoticamente de acordo com o perfil estipulado por $\frac{e^{-mr}}{r}$ **[2]**.
#
# $\quad$ Estabeleceremos, portanto, uma comparação direta entre essa previsão teórica e os resultados da nossa simulação. O propósito de cruzar essas informações é comprovar estruturalmente o projeto, atestando que o universo discreto e numérico que construímos a partir de ruído estocástico é, de fato, capaz de emular com fidelidade a lei física contínua que dita o comportamento e o emaranhamento do vácuo real.
#
# $\quad$ Para extrair o decaimento radial, precisamos mapear a distância de cada ponto da nossa grade em relação ao centro. Fazendo uso da função `np.meshgrid`, construímos uma matriz `R` onde o valor de cada pixel representa a sua distância $\Delta r$ em relação à origem da flutuação.

# %%
# Construção do mapa de distâncias radiais.
x = np.arange(-N//2, N//2) * (L/N)
y = np.arange(-N//2, N//2) * (L/N)
XX, YY = np.meshgrid(x, y)

# Matriz R contendo a distância de cada pixel até o centro (0,0).
R = np.sqrt(XX**2 + YY**2)

# %% [markdown]
# $\quad$ Com a matriz de distâncias criada, o próximo passo é agrupar os pontos por proximidade. O método `.flatten()` transforma as matrizes bidimensionais em vetores unidimensionais (listas lineares), facilitando a busca e o processamento computacional dos dados. A variável `bins` define intervalos de distância, funcionando como anéis concêntricos ao redor da origem. É fundamental notar que o limite máximo imposto para esses anéis no código é $L/2$. Essa escolha é feita propositalmente para evitar "efeitos de borda". Como a Transformada Rápida de Fourier (FFT) assume condições de contorno periódicas — tratando a grade espacial topologicamente como um toro —, distâncias maiores que $L/2$ começariam a se correlacionar erroneamente com a "imagem fantasma" da própria flutuação surgindo do lado oposto da grade.

# %%
# Achatamos as matrizes 2D para vetores 1D.
R_flat = R.flatten()
autocorr_flat = autocorr_2d_amostra.flatten()

# Definimos os anéis de distância (bins) parando em L/2.
bins = np.linspace(0, L/2, int(N/3))
bin_centers = 0.5 * (bins[1:] + bins[:-1])
radial_corr = np.zeros_like(bin_centers)

# %% [markdown]
# $\quad$ O bloco a seguir representa o núcleo do nosso tratamento de dados. O algoritmo varre cada anel de distância definido pelos *bins*. A variável `mask` atua como um filtro lógico, selecionando estritamente os pixels cuja distância radial recai dentro do anel atual. Em seguida, calcula-se a média (`np.mean`) da correlação de todos os pixels selecionados.
#
# $\quad$ Do ponto de vista físico, como o vácuo de Klein-Gordon é invariante sob rotações, a física subjacente depende exclusivamente da distância radial $r$, e não da direção angular. Realizar essa média varrendo todos os ângulos (uma média azimutal) cancela drasticamente qualquer ruído estatístico residual remanescente, isolando a verdadeira função de correlação de longo alcance.

# %%
# Extração da Média Azimutal
for i in range(len(bin_centers)):
    # Seleciona os pixels que caem dentro do anel atual
    mask = (R_flat >= bins[i]) & (R_flat < bins[i+1])
    
    # Se houver pixels nesse anel, calcula a média da correlação deles
    if np.any(mask):
        radial_corr[i] = np.mean(autocorr_flat[mask])

# %% [markdown]
# $\quad$ Na sequência, os dados simulados passarão por uma normalização crítica. Descartaremos o primeiro elemento dos vetores (índice 0, correspondente a $r \approx 0$) e dividiremos o restante da curva pelo valor do novo primeiro elemento (`corr_sim[0]`), forçando o gráfico a iniciar no valor $1$.
#
# $\quad$ Esse procedimento possui uma motivação física profunda: na Teoria Quântica de Campos contínua, a correlação de dois pontos no exato mesmo local do espaço diverge para o infinito (fenômeno conhecido como divergência ultravioleta, ou divergência UV). Na nossa rede espacial discreta, esse valor não chega ao infinito estatístico, mas é dominado de forma artificial pela resolução máxima da grade (o tamanho do pixel). Portanto, descartar a origem e normalizar os dados a partir de um raio estritamente positivo ($r > 0$) "ancora" o referencial. Isso nos permite comparar de forma justa a taxa de decaimento da curva sem que a singularidade na origem distorça a escala global do gráfico.

# %%
# Descartamos a origem (onde ocorre a divergência UV).
r_valido = bin_centers[1:]
corr_sim = radial_corr[1:]

# Normalizamos a curva simulada para começar em 1.
corr_sim = corr_sim / corr_sim[0]

# %% [markdown]
# $\quad$ Finalmente, construímos a curva teórica de comparação. Esse perfil analítico reflete a supressão exponencial probabilística de encontrarmos flutuações virtuais "vazando" por longas distâncias pelo espaço. A curva teórica é submetida ao exato mesmo processo de normalização para que ambas (teoria e simulação) possam ser sobrepostas perfeitamente a partir de $r > 0$. O trecho de código final cruza essas informações visualmente, plotando os resultados obtidos.

# %%
# Calculamos a previsão analítica (perfil: e^{-mr}/r).
corr_teorica = np.exp(-m * r_valido) / r_valido

# Aplicamos a mesma normalização para justa sobreposição.
corr_teorica = corr_teorica / corr_teorica[0]

# Plotando os resultados comparativos.
plt.figure(figsize=(7, 6), dpi=90)

plt.plot(r_valido, corr_sim, 'o-', label='Simulação (Média Radial)', markersize=4)
plt.plot(r_valido, corr_teorica, 'r--', label=r'Teoria $\frac{e^{-mr}}{r}$', linewidth=2)

plt.title('Decaimento da Correlação Radial no Vácuo')
plt.xlabel('Distância Radial $r$')
plt.ylabel(r'Correlação $\langle \phi(0)\phi(r) \rangle$ (Normalizada)')
plt.xlim(0, 3.0)

plt.legend()
plt.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# $\quad$ Ao analisarmos o gráfico resultante, observamos uma notável concordância entre os dados numéricos da simulação (pontos azuis) e a curva tracejada vermelha prevista pela QFT contínua. Essa sobreposição não é apenas um acerto matemático; ela consagra o sucesso absoluto do nosso modelo. O gráfico prova visualmente que, ao partirmos de um ruído puramente aleatório e o modularmos pelas leis da relatividade especial (através da relação de dispersão da energia), nós efetivamente recriamos a textura espacial do vácuo quântico dentro do computador. O formato da curva evidencia que o "nada" possui, de fato, uma topologia intrínseca de emaranhamento, onde uma flutuação em um ponto altera a probabilidade do que ocorre ao seu redor. O decaimento exponencial, regido pela massa $m$ da partícula, confirma que essa influência mútua despenca rapidamente a longas distâncias, isolando causalmente regiões muito afastadas do universo. Em suma, o nosso universo simulado e discreto capturou com sucesso a essência analítica e contínua do estado fundamental da matéria.
#
# $\quad$ Até o presente momento, a nossa análise tratou o vácuo como uma imagem estática, focando exclusivamente na estrutura espacial do correlação. No entanto, o universo não é congelado. As flutuações de ponto zero são entidades inerentemente dinâmicas que fervem — emergem e desaparecem continuamente — no tecido do espaço-tempo. Para capturar a verdadeira essência desse fenômeno, precisamos introduzir a dimensão temporal no nosso modelo. Na próxima seção, aplicaremos a matemática da evolução temporal aos modos do nosso campo, animando a configuração estática e dando vida à simulação do vácuo quântico.

# %% [markdown]
# ## 4. Evolução Temporal
#
# $\quad$ Assim como na Mecânica Quântica tradicional (onde a evolução de um estado é ditada pela multiplicação por uma fase complexa dependente da energia), a dinâmica na Teoria Quântica de Campos segue um princípio análogo. Esse comportamento se aplica diretamente aos operadores de criação e, o que é mais relevante para a nossa simulação do estado fundamental, aos operadores de aniquilação. A evolução temporal de um modo do campo com momento $\mathbf{p}$ (ou vetor de onda $\mathbf{k}$) é dada pela transformação **[2]**:
#
# $$\hat{a}_k \to e^{-i\omega_k t}\hat{a}_k.$$
#
# Lembrando novamente que, no nosso sistema de unidades naturais ($\hbar = c = 1$), energia e frequência angular são quantidades equivalentes ($\omega_k = E_k$).
#
# $\quad$ Primeiramente, vamos definir os parâmetros fundamentais da nossa animação, como o número total de quadros (`num_frames`) e o incremento de tempo (`dt`) entre eles. Além disso, faremos uma cópia da nossa matriz original no espaço dos momentos (`phi_k`) para servir como o "tempo zero" da simulação.
#
# $\quad$ Para garantir que a visualização seja fiel, utilizaremos um truque gráfico: calculamos a Transformada de Fourier do primeiro quadro para ancorar a escala de cores (`vmin` e `vmax`). Fixar essa escala é essencial; se não o fizéssemos, o `Matplotlib` reajustaria o brilho a cada quadro, criando um efeito estroboscópico falso que mascararia a verdadeira variação de amplitude das ondas.

# %%
num_frames = 100    # Número de quadros da animação.
dt = 0.1            # Tamanho do passo de tempo matemático entre os quadros.

# Configuração inicial do campo (guardamos o t=0 para aplicar a fase depois).
phi_k_inicial = phi_k.copy()

# Preparação Visual da Animação.
fig, ax = plt.subplots(figsize=(7, 6), dpi=60)
ax.set_title("Evolução das Flutuações do Vácuo Quântico")
ax.set_xlabel("Espaço X")
ax.set_ylabel("Espaço Y")

# Geramos fisicamente o primeiro quadro no tempo t=0 para inicializar a imagem.
campo_t0 = np.real(np.fft.ifft2(phi_k_inicial))

# Travando a escala de cores: usamos percentis do quadro inicial para ignorar picos estatísticos muito anômalos e maximizar o contraste das flutuações reais.
limite_max = np.percentile(campo_t0, 99)
limite_min = np.percentile(campo_t0, 1)

# Passamos vmin e vmax diretamente na criação da imagem, que será atualizada depois.
im = ax.imshow(
    campo_t0, 
    cmap='magma', 
    extent=[-L/2, L/2, -L/2, L/2], 
    origin='lower',
    animated=True, 
    vmin=limite_min, 
    vmax=limite_max
)
fig.colorbar(im, ax=ax, label='Amplitude do Campo')

# %% [markdown]
# $\quad$ Com a estrutura visual preparada, o próximo passo é definir a função de atualização, que atuará como o "motor do tempo" da nossa animação.
#
# $\quad$ A lógica computacional aqui é muito elegante: a evolução não é feita no espaço real, mas sim no espaço dos momentos. A cada novo quadro, pegamos a configuração inicial `phi_k_inicial` e a multiplicamos pela fase complexa temporal $e^{-i\omega_k t}$. Como `omega_k` é uma matriz contendo as diferentes frequências para cada comprimento de onda, os modos de alta energia (ondas curtas) oscilarão muito rápido, enquanto os modos de baixa energia (ondas longas) oscilarão lentamente — exatamente como dita a relatividade especial. Após atualizar o espaço dos momentos, aplicamos a Transformada Inversa de Fourier para devolver a imagem atualizada ao espaço real das posições físicas.

# %%
def update(frame):
    # Calcula o instante de tempo atual.
    t = frame * dt
    
    # Multiplicamos a amplitude inicial pela fase quântica.
    fase_temporal = np.exp(-1j * omega_k * t)
    phi_k_t = phi_k_inicial * fase_temporal
    
    # Transformada Inversa para trazer a configuração de volta ao espaço físico real.
    campo_fisico_t = np.real(np.fft.ifft2(phi_k_t))
    
    # Atualiza estritamente os dados numéricos da imagem (mantendo a escala travada).
    im.set_array(campo_fisico_t)
    
    return [im]

# %% [markdown]
# $\quad$ Finalmente, utilizamos a biblioteca de animação do `Matplotlib` para executar a função de atualização em laço. O código itera sobre o número de quadros especificado, compila a evolução contínua das flutuações no espaço real e empacota o resultado final na forma de um arquivo GIF, permitindo-nos visualizar o fervilhar caótico e intrinsecamente harmônico do vácuo quântico.

# %%
# Gerando o GIF
ani = animation.FuncAnimation(fig, update, frames=num_frames, interval=100, blit=True)

# Salvando o GIF.
ani.save('vacuo_quantico.gif', writer='pillow', fps=15)
plt.close(fig) # Fecha a figura estática para não duplicar a imagem no Notebook.

# %% [markdown]
# ![Evolução do Vácuo Quântico](https://raw.githubusercontent.com/Wally-sson/pys/main/Flutua%C3%A7%C3%A3o%20do%20V%C3%A1cuo/vacuo_quantico.gif)
#
# $\quad$ Ao observarmos a animação gerada, contemplamos a verdadeira natureza dinâmica do vácuo quântico. O que vemos no gráfico não é um espaço estático ou vazio, mas um mar revolto de energia em constante transição. As regiões de pico e vale (cores quentes e frias) representam a criação e a aniquilação efêmeras de partículas virtuais borbulhando no tecido do espaço-tempo.
#
# $\quad$ Um detalhe físico crucial revelado por essa animação é o ritmo dessas oscilações. Graças à fase de evolução quântica ($e^{-i\omega_k t}$), cujo ritmo $\omega_k$ é ditado pela relação de dispersão relativística, podemos notar que as ondulações mais amplas (modos de onda longos, de menor energia) evoluem de forma mais lenta e suave. Em contrapartida, a "granulação" fina do gráfico (modos de onda curtos, de alta energia) pisca e desaparece quase instantaneamente. Esse comportamento obedece fielmente ao Princípio da Incerteza de Heisenberg ($\Delta E \Delta t \ge 1/2$, em unidades naturais): flutuações que tomam "emprestada" muita energia do vácuo só podem existir por frações de tempo minúsculas. Essa animação é, portanto, a representação visual direta da mecânica quântica e da relatividade especial ditando juntas o ritmo do universo no seu estado mais fundamental.
#
# $\quad$ Até agora, animamos a passagem do tempo para uma única configuração do vácuo. Contudo, para consolidarmos todo o conhecimento matemático e computacional construído ao longo deste trabalho, podemos dar um passo ainda mais ambicioso. E se pudéssemos visualizar, simultaneamente e em tempo real, a geração contínua de múltiplos universos independentes, observando o ruído caótico de cada amostra estabilizando, quadro a quadro, até convergir para a suave simetria da teoria analítica? Na próxima seção, uniremos todas as etapas do nosso projeto em um único painel dinâmico.

# %% [markdown]
# ## 5. Evolução Simultânea
#
# $\quad$ Nesta etapa final, não vamos evoluir um único vácuo no tempo físico. Em vez disso, a nossa animação iterará sobre a criação de novos "microestados" independentes. A cada quadro, sortearemos um novo universo aleatório. O nosso objetivo é construir um painel com quatro gráficos simultâneos: o campo físico, a autocorrelação instantânea, a média da amostra e o decaimento radial.
#
# $\quad$ Como estamos operando em um ambiente de `Notebook` (PRECISA DE ` `"?), não precisamos recalcular as matrizes de frequência (`omega_k`) ou as configurações da curva teórica (`corr_teorica`, `bins`, etc.), pois elas já estão armazenadas na memória do kernel. Apenas utilizaremos um truque preparatório: geraremos um universo "fantasma" estritamente para descobrir os limites ideais da escala de cores (`vmin` e `vmax`). Fixar esses limites é vital para impedir que o gráfico "pisque" descontroladamente a cada novo sorteio estatístico.

# %%
# Geramos um universo "fantasma" só para descobrir qual deve ser o limite do colormap.
ruido_r_dummy = np.random.normal(0, 1, (N, N))
ruido_i_dummy = np.random.normal(0, 1, (N, N))

# Aproveitamos o omega_k que já está na memória.
phi_k_dummy = ((ruido_r_dummy + 1j * ruido_i_dummy) / np.sqrt(2)) / np.sqrt(2 * omega_k)

espectro_dummy = np.abs(phi_k_dummy)**2
espectro_dummy[0, 0] = 0
autocorr_dummy = np.fft.fftshift(np.real(np.fft.ifft2(espectro_dummy)))

# Fixamos o vmax no percentil 99 para não ofuscar as bordas suaves.
vmax_fixo = np.percentile(autocorr_dummy, 99) 
vmin_fixo = np.min(autocorr_dummy) # Capta o "fundo do poço" das correlações negativas.

# %% [markdown]
# $\quad$ Com a matemática de base ancorada, configuramos o layout visual usando o Matplotlib. O comando `plt.subplots(2, 2)` criará uma grade com duas linhas e duas colunas, abrigando os nossos quatro gráficos. Também inicializamos a matriz `soma_espectro` com zeros, pois ela será a responsável por acumular as médias de todos os frames ao longo da execução.

# %%
fig, axs = plt.subplots(2, 2, figsize=(10, 10), dpi=60)

# Desempacota a matriz 2x2 em 4 eixos individuais para facilitar o manuseio.
ax1, ax2, ax3, ax4 = axs.flatten() 
fig.tight_layout(pad=4.0)

# Matriz global que acumulará os espectros para o cálculo da amostra.
soma_espectro = np.zeros((N, N))

# Fechamos a figura estática para não poluir o Notebook, focando no GIF final.
plt.close(fig)

# %% [markdown]
# $\quad$ Agora definimos a função principal de atualização (`atualizar`). O fluxo interno dela reproduz de forma acelerada tudo o que dissecamos nas seções anteriores. Ela limpa o gráfico anterior, gera ruído quântico novo, aplica a relação de dispersão para gerar o campo físico e usa o Teorema de Wiener-Khinchin para achar a correlação daquele instante.
#
# $\quad$ O ponto alto desta função é a etapa do amostra estatística: ela soma a configuração recém-gerada ao acumulador e divide pelo número do quadro atual (`frame + 1`), gerando uma média móvel. Visualmente, o gráfico da amostra começará ruidoso, mas à medida que o laço avança, os ruídos se cancelarão e o padrão isotrópico florescerá de forma orgânica.

# %%
def atualizar(frame):
    global soma_espectro
    
    # Limpa os eixos para desenhar o novo quadro.
    ax1.clear(); ax2.clear(); ax3.clear(); ax4.clear()
    
    # Gera um novo vácuo a cada frame.
    ruido_real = np.random.normal(0, 1, (N, N))
    ruido_imag = np.random.normal(0, 1, (N, N))
    phi_k = ((ruido_real + 1j * ruido_imag) / np.sqrt(2)) / np.sqrt(2 * omega_k)
    
    # Campo Real Instantâneo.
    phi_x = np.real(np.fft.ifft2(phi_k))
    
    # Autocorrelação Instantânea.
    espectro_inst = np.abs(phi_k)**2
    espectro_inst[0, 0] = 0 
    autocorr_inst = np.fft.fftshift(np.real(np.fft.ifft2(espectro_inst)))
    
    # Cálculo da Média Móvel (Ensemble).
    soma_espectro += espectro_inst
    espectro_medio = soma_espectro / (frame + 1)
    autocorr_media = np.fft.fftshift(np.real(np.fft.ifft2(espectro_medio)))
    
    # Média Radial da Autocorrelação
    # Utilizamos a matriz 'R' e os 'bins' que JÁ ESTÃO na memória global (Seção 3.3)
    radial_corr = np.zeros_like(bin_centers)
    for i in range(len(bin_centers)):
        mask = (R >= bins[i]) & (R < bins[i+1])
        if np.any(mask):
            # Extraímos o decaimento a partir da matriz que está convergindo.
            radial_corr[i] = np.mean(autocorr_media[mask]) 
            
    corr_sim = radial_corr[1:]
    corr_sim = corr_sim / corr_sim[0] # Normalização.
    
    # Plots: 
    
    # Campo Físico
    ax1.imshow(phi_x, cmap='RdBu', extent=[-L/2, L/2, -L/2, L/2], origin='lower')
    ax1.set_title(f'Campo Físico Instantâneo\n(Universo {frame+1})')
    
    # Autocorrelação 2D Instantânea.
    ax2.imshow(autocorr_inst, cmap='viridis', extent=[-L/2, L/2, -L/2, L/2], origin='lower', vmax=vmax_fixo, vmin=vmin_fixo)
    ax2.set_title('Autocorrelação 2D Instantânea\n(Ruidosa)')
    
    # Autocorrelação 2D Média (Ensemble).
    ax3.imshow(autocorr_media, cmap='viridis', extent=[-L/2, L/2, -L/2, L/2], origin='lower', vmax=vmax_fixo, vmin=vmin_fixo)
    ax3.set_title(f'Média do Ensemble (N={frame+1})\n(Convergindo)')
    
    # Curva Radial vs Teoria.
    ax4.plot(r_valido, corr_sim, 'o-', label='Amostra', markersize=4)
    ax4.plot(r_valido, corr_teorica, 'r--', label='Teoria', linewidth=2)
    ax4.set_title('Decaimento Radial\n(Convergência Estatística)')
    ax4.set_xlim(0, 3.0); ax4.set_ylim(-0.2, 1.2)
    ax4.legend(loc='upper right')
    ax4.grid(True, alpha=0.3) 
    
    return []

# %% [markdown]
# $\quad$ Para fechar o trabalho, empacotamos o painel interativo. O código executa o processo para cada quadro definido e salva o arquivo iterativo resultante. Este GIF é a evidência computacional final da nossa jornada pela Teoria Quântica de Campos: provando visualmente como o universo físico emerge rigorosamente a partir da probabilidade e do caos estatístico.

# %%
# Criando a animação.
ani = animation.FuncAnimation(fig, atualizar, frames=num_frames, interval=150, blit=True)

# Salva o arquivo.
ani.save('evolucao_vacuo_quantico.gif', writer='pillow')

# %% [markdown]
# ![Evolução Simultânea e Convergência](https://raw.githubusercontent.com/Wally-sson/pys/main/Flutua%C3%A7%C3%A3o%20do%20V%C3%A1cuo/evolucao_vacuo_quantico.gif)
#
# $\quad$ Ao observarmos o painel dinâmico gerado, presenciamos a essência da física estatística e da Teoria Quântica de Campos em plena ação. Na parte superior do dashboard, vemos a natureza efêmera e caótica de cada "universo" individual: o campo físico ferve de forma imprevisível e a sua autocorrelação instantânea é severamente distorcida pelo ruído quântico. Contudo, ao voltarmos a nossa atenção para a parte inferior do painel, obsevamos a convergência dos gráficos.
#
# $\quad$ Conforme os quadros avançam e o acumulador da amostra processa mais microestados, as flutuações aleatórias se cancelam mutuamente. O mapa de calor da média converge gradativamente para um halo perfeitamente simétrico e isotrópico. Simultaneamente, no gráfico de decaimento radial, os pontos da simulação — inicialmente trêmulos e dispersos — são puxados de forma implacável para cima da rigorosa curva teórica contínua, $\frac{e^{-mr}}{r}$. Este GIF final não é apenas uma bela demonstração visual; ele é a prova computacional definitiva de que a ordem intrínseca e as leis fundamentais do universo repousam, em sua essência, sobre a sinfonia caótica e probabilística do vácuo quântico.

# %% [markdown]
# ## 6. Conclusão
#
# $\quad$ O desenvolvimento deste projeto representa um triunfo prático na ponte entre a matemática abstrata da Teoria Quântica de Campos (QFT) e a física computacional. Conseguimos traduzir com sucesso o comportamento contínuo do estado fundamental do universo para um laboratório numérico discreto. Ao partirmos de ruído puramente estocástico e o modularmos através da relação de dispersão relativística de um campo de Klein-Gordon, provamos visual e matematicamente que o "nada" está longe de ser um espaço vazio. Em vez disso, emulamos um tecido dinâmico e fervilhante de energia, onde o emaranhamento espacial e a evolução temporal das flutuações virtuais obedecem estritamente às regras combinadas do Princípio da Incerteza e da Relatividade Especial.
#
# $\quad$ A maior consagração da nossa simulação, no entanto, residiu na convergência estatística. Enquanto a observação de um único instante do vácuo revelou um cenário caótico e dominado por ruído branco, a construção computacional do ensemble nos permitiu extrair a ordem profunda subjacente a esse caos. Assistir às flutuações aleatórias se cancelarem mutuamente para dar lugar a uma simetria isotrópica perfeita — culminando no exato decaimento radial previsto analiticamente pela função $\frac{e^{-mr}}{r}$ — atesta a absoluta fidelidade do modelo. Este trabalho não apenas valida de forma palpável os postulados teóricos da QFT, mas demonstra a profunda elegância de como as leis determinísticas e estruturais da realidade emergem diretamente de um mar de probabilidades quânticas.

# %% [markdown]
# ## Referências
#
# **[1]** PIRES, Antônio S. T. Evolução das ideias da Física. 2. ed. São Paulo: Livraria da Física, 2011.
#
# **[2]** T. Lancaster e S. J. Blundell, Quantum Field Theory for the Gifted Amateur.
# Oxford University Press, 1ª ed., 2014.
#
# **[3]** M. E. Peskin e D. V. Schroeder, An Introduction to Quantum Field Theory. Addison-Wesley, 1995.
#
# **[4]** PAPOULIS, A.; PILLAI, S. U. Probability, Random Variables, and Stochastic Processes. 4. ed. Nova York: McGraw-Hill, 2002.
#
# **[5]** PRESS, W. H. et al. Numerical Recipes: The Art of Scientific Computing. 3. ed. Cambridge: Cambridge University Press, 2007.
